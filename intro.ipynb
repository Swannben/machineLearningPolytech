# %% [markdown]
# # TP introduction to Machine Learning
# Diane Lingrand (diane.lingrand@univ-cotedazur)
#
# Julie Tores (julie.tores@univ-cotedazur.fr ou julie.tores@etu.univ-cotedazur.fr)
#
# Polytech, SI4, 2023-24

# %%
#necessary imports
from sklearn import datasets
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## dataset: Iris

# %%
# loading the dataset
iris = datasets.load_iris()
X = iris.data
y = iris.target

# %% [markdown]
# **Question 1:** how many data ?

# %%
# your code
len(X)
# Out:
# 150

# %% [markdown]
# **Question 2**: type of data ? dimension of data ? type of labels ?

# %%
# your code
print(X.shape[1])
print(type(X[0][0]))
print(type(y[0]))
# Out:
# 4
# <class 'numpy.float64'>
# <class 'numpy.int32'>

# %% [markdown]
# **Question 3:** How many classes ? How many samples per class ?

# %%
print(len(np.unique(y)))

print(np.unique(y,return_counts=True))
# Out:
# 3
# (array([0, 1, 2]), array([50, 50, 50], dtype=int64))

# %% [markdown]
# **Question 4:** choose 2 dimensions and plot the data in the plane using a different color for each class.

# %%
# your code
colors= ['g','y','r']
plt.scatter(X[:,0],X[:,3], c=y[:])

# %% [markdown]
# **Question 5:** perfect classification. What are the metrics values ? Read the documention of metrics function in scikit-learn: https://scikit-learn.org/stable/modules/model_evaluation.html#classification-metrics

# %%
from sklearn.metrics import *

# here is an example for accuracy: 
print("accuracy of the perfect classification", accuracy_score(y, y))

# plot also the recall, F1-measures, confusion matrix
print("recall of the perfect classification", recall_score(y, y,average="macro"))
print("f1 of the perfect classification", f1_score(y, y,average="macro"))

ConfusionMatrixDisplay.from_predictions(y, y)
# your code
# Out:
# accuracy of the perfect classification 1.0
# recall of the perfect classification 1.0
# f1 of the perfect classification 1.0

# %% [markdown]
# **Question 6**: random classification. What are the metrics values ? <br/>
# *Hint*: use https://numpy.org/doc/stable/reference/random/generated/numpy.random.randint.html for the generation of random labels. <br/>
# Don't forget the confusion matrix. Hint: ConfusionMatrixDisplay https://scikit-learn.org/stable/modules/generated/sklearn.metrics.ConfusionMatrixDisplay.html#sklearn.metrics.ConfusionMatrixDisplay.from_predictions

# %%
randy=[]
for i in range(len(y)):
    randy.append(np.random.randint(0,3))
print("accuracy of the random classification", accuracy_score(y, randy))

print("recall of the random classification", recall_score(y, randy,average="macro"))
print("f1 of the random classification", f1_score(y, randy,average="macro"))

ConfusionMatrixDisplay.from_predictions(y, randy)
# Out:
# accuracy of the random classification 0.36666666666666664
# recall of the random classification 0.3666666666666667
# f1 of the random classification 0.36590236177098395

# %%
def show_classif_metrics(y,randy,average="macro"):
        
    print("accuracy of the classification", accuracy_score(y, randy))

    print("recall of the classification", recall_score(y, randy,average=average))
    print("f1 of the classification", f1_score(y, randy,average=average))

    ConfusionMatrixDisplay.from_predictions(y, randy)

# %% [markdown]
# ### binary classification

# %%
# we choose to remove class with label 2 (Iris Virginica)
XBinaire = X[y!=2]
yBinaire = y[y!=2]
print(XBinaire.shape)
# Out:
# (100, 4)

# %%
# split into train and test datasets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(XBinaire, yBinaire, test_size=0.4)

# %% [markdown]
# **Question 7**: Try to build a classifier better than the random one, use the thresholding on one or more component. Choose the thresholds using the train dataset and compute the metrics on the test dataset.

# %%
plt.scatter(X_train[:,0],X_train[:,2], c=y_train[:])

y_pred=[]
for i in X_test:
    if i[2]>2.5:
        y_pred.append(1)
    else:
        y_pred.append(0)

show_classif_metrics(y_test,y_pred)
# Out:
# accuracy of the classification 1.0
# recall of the classification 1.0
# f1 of the classification 1.0

# %% [markdown]
# **Question 8**: Using this method, could you propose an algorithm for classifying the 3 classes?

# %%
plt.scatter(X[:,0],X[:,3], c=y[:])

y_pred=[]
for i in X:
    if i[3]>1.8:
        y_pred.append(2)
    elif i[3]<0.8:
        y_pred.append(0)
    else:
        y_pred.append(1)
show_classif_metrics(y,y_pred)
# Out:
# accuracy of the classification 0.8933333333333333
# recall of the classification 0.8933333333333334
# f1 of the classification 0.8905309250136836

# %% [markdown]
# ## dataset: digit

# %%
# reading the dataset
digits = datasets.load_digits()
X = digits.data
y = digits.target

# %%
#display one of the pictures (the 22th in this code)
import matplotlib.pyplot as plt
i = 22 #index of the image: change it in order to display other images
plt.imshow(X[i].reshape((8,8)),aspect="auto",cmap='gray')
plt.show()
print('class = ', y[i])
# Out:
# class =  2

# %% [markdown]
# **Question 9**: Using the digit dataset, answer again to the previous questions from 1 to 8.

# %%
# your code

print(len(X))
print(X.shape[1])
print(type(X[0][0]))
print(type(y[0]))
# Out:
# 1797
# (1797, 64)
# <class 'numpy.float64'>
# <class 'numpy.int32'>
